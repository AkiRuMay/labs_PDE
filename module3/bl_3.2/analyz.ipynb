# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Загрузка данных с пропуском первого столбца
df = pd.read_csv('data.csv').iloc[:, 1:]

def plot_horizontal_bars(values, labels, heading, color_scheme='plasma'):
    """Визуализация горизонтальных бар-чартов с подавлением легенды"""
    plt.figure(figsize=(9, 5))
    sns.barplot(
        x=values,
        y=labels,
        hue=labels,  # Добавляем hue для соответствия требованиям
        palette=color_scheme,
        legend=False  # Отключаем избыточную легенду
    )
    plt.title(heading)
    plt.xlabel('Количество ответов')
    plt.ylabel('Варианты выбора')
    plt.tight_layout()
    plt.show()

def process_composite_answers(response_series, question_text):
    """Обработка вопросов с множественными ответами"""
    split_responses = response_series.dropna().str.split(';')
    flattened_responses = split_responses.explode()
    response_counts = flattened_responses.value_counts()
    
    print(f"\nРезультаты анализа: {question_text}")
    print(response_counts.to_string())
    
    plot_horizontal_bars(
        response_counts.values,
        response_counts.index,
        f"Распределение ответов: {question_text}"
    )

def handle_rating_questions(response_series, question_text):
    """Анализ вопросов с рейтинговой шкалой"""
    average_score = response_series.mean()
    frequency_distribution = response_series.value_counts().sort_index()
    
    print(f"\nАнализ рейтинга: {question_text}")
    print(f"Средняя оценка: {round(average_score, 2)}")
    print(frequency_distribution.to_string())
    
    plt.figure(figsize=(7, 4))
    sns.countplot(
        x=response_series,
        hue=response_series,  # Добавляем hue
        palette='rocket',
        legend=False,  # Отключаем легенду
        order=sorted(response_series.unique())
    )
    plt.title(f"Распределение оценок: {question_text}")
    plt.xlabel('Баллы')
    plt.ylabel('Количество участников')
    plt.tight_layout()
    plt.show()

def handle_exclusive_choice(response_series, question_text):
    """Обработка вопросов с единственным выбором"""
    choice_counts = response_series.value_counts()
    
    print(f"\nСтатистика для: {question_text}")
    print(choice_counts.to_string())
    
    plot_horizontal_bars(
        choice_counts.values,
        choice_counts.index,
        f"Распределение ответов: {question_text}",
        'mako'
    )

def perform_comprehensive_analysis(dataset):
    """Основная функция анализа данных"""
    for column in dataset:
        print(f"\n=== Анализ колонки: {column} ===")
        current_data = dataset[column]
        
        if pd.api.types.is_string_dtype(current_data):
            if current_data.str.contains(';', na=False).any():
                process_composite_answers(current_data, column)
            else:
                handle_exclusive_choice(current_data, column)
        elif np.issubdtype(current_data.dtype, np.number):
            handle_rating_questions(current_data, column)
        else:
            print(f"Неподдерживаемый формат данных в колонке: {column}")

# Запуск анализа
perform_comprehensive_analysis(df)
# Out:
# === Анализ колонки: Как давно вы работаете в IT-отрасли? ===
#
# Статистика для: Как давно вы работаете в IT-отрасли?
# Как давно вы работаете в IT-отрасли?
# Менее 1 года    4
# 1-3 года        2
# === Анализ колонки: Как давно ваша компания использует Data Lake? ===
#
# Статистика для: Как давно ваша компания использует Data Lake?
# Как давно ваша компания использует Data Lake?
# 3-5 лет         3
# Менее 1 года    2
# 1-2 года        1
# === Анализ колонки: Уровень экспертизы ===
#
# Анализ рейтинга: Уровень экспертизы
# Средняя оценка: 3.33
# Уровень экспертизы
# 2    2
# 3    1
# 4    2
# 5    1
# === Анализ колонки: В каких аспектах Data Lake вы наиболее компетентны? (можно выбрать несколько) ===
#
# Статистика для: В каких аспектах Data Lake вы наиболее компетентны? (можно выбрать несколько)
# В каких аспектах Data Lake вы наиболее компетентны? (можно выбрать несколько)
# Архитектура решения, Обработка данных, Анализ данных, Управление проектами    1
# Архитектура решения, Безопасность, Анализ данных                              1
# Анализ данных                                                                 1
# Безопасность, Управление проектами                                            1
# Безопасность                                                                  1
# Обработка данных, Безопасность, Анализ данных                                 1
# === Анализ колонки: Типы данных в вашем Data Lake: ===
#
# Статистика для: Типы данных в вашем Data Lake:
# Типы данных в вашем Data Lake:
# Только структурированные (таблицы, CSV)                                                                           2
# Только структурированные (таблицы, CSV), Полуструктурированные (JSON, XML), Неструктурированные (текст, видео)    1
# Обработка данных                                                                                                  1
# Обработка данных, Потоковые данные (IoT, Kafka)                                                                   1
# Неструктурированные (текст, видео), Потоковые данные (IoT, Kafka)                                                 1
# /tmp/ipykernel_1537119/2367169947.py:22: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# === Анализ колонки: Какой тип хранилища данных используется в вашей компании? ===
#
# Статистика для: Какой тип хранилища данных используется в вашей компании?
# Какой тип хранилища данных используется в вашей компании?
# Облачное хранилище     4
# Локальное хранилище    1
# Гибридное решение      1
# === Анализ колонки: Какие инструменты обработки данных применяются? (выберите несколько) ===
#
# Статистика для: Какие инструменты обработки данных применяются? (выберите несколько)
# Какие инструменты обработки данных применяются? (выберите несколько)
# Apache Spark, Apache Flink, Databricks, Snowflake, Dremio    1
# Apache Spark, Databricks, Snowflake                          1
# Apache Spark, Snowflake                                      1
# Databricks, Dremio                                           1
# Databricks                                                   1
# Apache Spark, Apache Flink                                   1
# === Анализ колонки: Оцените свой вклад в развитие Data Lake в компании ===
#
# Анализ рейтинга: Оцените свой вклад в развитие Data Lake в компании
# Средняя оценка: 3.0
# Оцените свой вклад в развитие Data Lake в компании
# 1    1
# 3    4
# 5    1
# === Анализ колонки: Оценка компонентов Data Lake [Архитектура решения] ===
#
# Статистика для: Оценка компонентов Data Lake [Архитектура решения]
# Оценка компонентов Data Lake [Архитектура решения]
# Удовлетворительно    2
# Хорошо               2
# Отлично              1
# Очень плохо          1
# === Анализ колонки: Оценка компонентов Data Lake [Обработка данных] ===
# Неподдерживаемый формат данных в колонке: Оценка компонентов Data Lake [Обработка данных]
#
# === Анализ колонки: Оценка компонентов Data Lake [Безопасность] ===
#
# Статистика для: Оценка компонентов Data Lake [Безопасность]
# Оценка компонентов Data Lake [Безопасность]
# Удовлетворительно    2
# Хорошо               2
# Отлично              1
# Очень плохо          1
# === Анализ колонки: Оценка компонентов Data Lake [Анализ данных] ===
# Неподдерживаемый формат данных в колонке: Оценка компонентов Data Lake [Анализ данных]
#
# === Анализ колонки: Оценка компонентов Data Lake [Управление метаданными] ===
#
# Статистика для: Оценка компонентов Data Lake [Управление метаданными]
# Оценка компонентов Data Lake [Управление метаданными]
# Хорошо               2
# Удовлетворительно    2
# Плохо                1
# Отлично              1
# === Анализ колонки: Оценка компонентов Data Lake [Интеграция с системами] ===
#
# Статистика для: Оценка компонентов Data Lake [Интеграция с системами]
# Оценка компонентов Data Lake [Интеграция с системами]
# Хорошо               3
# Отлично              1
# Удовлетворительно    1
# Очень плохо          1
# === Анализ колонки: Оценка компонентов Data Lake [Качество данных] ===
#
# Статистика для: Оценка компонентов Data Lake [Качество данных]
# Оценка компонентов Data Lake [Качество данных]
# Отлично              2
# Очень плохо          2
# Удовлетворительно    1
# Хорошо               1
# === Анализ колонки: Оценка компонентов Data Lake [Доступность данных] ===
#
# Статистика для: Оценка компонентов Data Lake [Доступность данных]
# Оценка компонентов Data Lake [Доступность данных]
# Удовлетворительно    2
# Хорошо               2
# Отлично              1
# Плохо                1
# === Анализ колонки: Оценка компонентов Data Lake [Масштабируемость] ===
#
# Статистика для: Оценка компонентов Data Lake [Масштабируемость]
# Оценка компонентов Data Lake [Масштабируемость]
# Удовлетворительно    2
# Хорошо               2
# Очень плохо          2
# === Анализ колонки: Оценка компонентов Data Lake [Стоимость владения] ===
#
# Статистика для: Оценка компонентов Data Lake [Стоимость владения]
# Оценка компонентов Data Lake [Стоимость владения]
# Удовлетворительно    2
# Хорошо               2
# Очень плохо          1
# Плохо                1
# === Анализ колонки: Основные сложности при внедрении (выберите до 3): ===
#
# Статистика для: Основные сложности при внедрении (выберите до 3):
# Основные сложности при внедрении (выберите до 3):
# Высокие затраты, Нехватка экспертизы, Ограничения инфраструктуры           1
# Нехватка экспертизы, Ограничения инфраструктуры                            1
# Нехватка экспертизы, Проблемы с качеством данных, Сопротивление команды    1
# Нехватка экспертизы, Сопротивление команды                                 1
# Высокие затраты                                                            1
# Нехватка экспертизы, Проблемы с качеством данных                           1
# === Анализ колонки: Какие меры безопасности используются? (выберите несколько) ===
#
# Статистика для: Какие меры безопасности используются? (выберите несколько)
# Какие меры безопасности используются? (выберите несколько)
# Аудит действий           4
# Шифрование данных        1
# Ролевой доступ (RBAC)    1
# === Анализ колонки: Какие улучшения планируются? (выберите несколько): ===
#
# Статистика для: Какие улучшения планируются? (выберите несколько):
# Какие улучшения планируются? (выберите несколько):
# Миграция в облако, Улучшение безопасности                                                                                 2
# Внедрение AI/ML-моделей, Миграция в облако, Улучшение безопасности, Оптимизация хранения, Расширение источников данных    1
# Внедрение AI/ML-моделей, Оптимизация хранения                                                                             1
# Улучшение безопасности                                                                                                    1
# Улучшение безопасности, Оптимизация хранения                                                                              1
# /tmp/ipykernel_1537119/2367169947.py:22: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# === Анализ колонки: Рекомендуете ли Data Lake другим компаниям? ===
#
# Статистика для: Рекомендуете ли Data Lake другим компаниям?
# Рекомендуете ли Data Lake другим компаниям?
# Да, безусловно            5
# Да, но с учетом рисков    1
